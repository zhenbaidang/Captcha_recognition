# %%
import zhenbot

# %%
zhenb = zhenbot.ZhenBot(ocr=False, det=False, slide=True)

# %%
img_base64 = '...'

# %%
im, im0 = zhenbot.img_bs64_to_det_model_input_tensor(img_base64)
zhenb.slide_inference(im, im0)
# Out:
# (0.5319444537162781,
#  0.7464285492897034,
#  0.13611111044883728,
#  0.3499999940395355,
#  tensor(0.9756))

# %%
im.shape
# Out:
# torch.Size([1, 3, 256, 640])
